# %%
pip install nltk
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 4.5 MB/s eta 0:00:01:01
# ...
#      |████████████████████████████████| 748 kB 28.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 8.6 MB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk

# %%
# %%writefile text.txt
# jjjjjjjjjjfjldf jfdljdflsjlfj   fdlkdlfjlsd flsjdfl
# Out:
# Writing text.txt

# %%
file = open('text.txt')
file.read()
# Out:
# 'jjjjjjjjjjfjldf jfdljdflsjlfj   fdlkdlfjlsd flsjdfl\n'

# %%
file.readlines()
# Out:
# []

# %%
file.seek(10)
# Out:
# 10
